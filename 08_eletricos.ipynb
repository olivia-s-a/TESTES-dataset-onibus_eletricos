# %% [markdown]
# ## Ônibus elétricos

# %% [markdown]
# Nesse notebook é feita uma análise dos ônibus elétricos

# %% [markdown]
# Os dados foram disponibilizados pela SMT e incluídos manualmente na pasta "data" do projeto

# %%
import pandas as pd
from utils.load_csv import load_csv

# %%
df_eletricos = load_csv('Ônibus elétricos a bateria - 15 09 2025 - última(POR LOTE).csv')

df_eletricos
# Out:
#               Assessoria do Cadastro da Frota e dos Operadores - DO/ACF  \
# 0                                                  NaN
# 1              VEÍCULOS MOVIDOS A BATERIA - 15/09/2025
# 2                                                  NaN
# 3                                                 Lote
# 4                                                 AR0
# ..                                                 ...
# 772                                                NaN
# 773                                                NaN
# 774                                                NaN
# 775                                                NaN
# 776                                                NaN
#
#     Unnamed: 1                      Unnamed: 2          Unnamed: 3  \
# 0          NaN                             NaN                 NaN
# 1          NaN                             NaN                 NaN
# 2          NaN                             NaN                 NaN
# 3      Empresa                         Prefixo               Placa
# 4    Ambiental                           41100            GEV7G11
# ..         ...                             ...                 ...
# 772        NaN                             D12          AUTO BLESS
# 773        NaN                             D12  AUTO BLESS - Teste
# 774        NaN                             D13        ALFA RODOBUS
# 775        NaN  TOTAL GRUPO LOCAL DISTRIBUIÇÃO                 NaN
# 776        NaN                     TOTAL GERAL                 NaN
#
#              Unnamed: 4        Unnamed: 5       Unnamed: 6   Unnamed: 7  \
# 0                   NaN               NaN              NaN          NaN
# 1                   NaN               NaN              NaN          NaN
# 2                   NaN               NaN              NaN          NaN
# 3                Chassi  Data de Inclusão  Tipo de Vínculo   Tecnologia
# 4    96JE3M39URB000002        11/09/2023       Patrimonial  ePadron 15M
# ..                  ...               ...              ...          ...
# 772                  89               NaN              NaN          NaN
# 773                   1               NaN              NaN          NaN
# 774                  10               NaN              NaN          NaN
# 775                 297               NaN              NaN          NaN
# 776                 731               NaN              NaN          NaN
#
#                   Unnamed: 8                      Unnamed: 9  ... Unnamed: 23  \
# 0                        NaN                             NaN  ...         NaN
# 1                        NaN                             NaN  ...         NaN
# 2                        NaN                             NaN  ...         NaN
# 3    Marca/Modelo Carroceria             Marca/Modelo Chassi  ...         NaN
# 4         Caio - eMillennium  Scania/Eletra - K310 UB 6x2*4   ...         NaN
# ..                       ...                             ...  ...         ...
# 772                      NaN                             NaN  ...         NaN
# 773                      NaN                             NaN  ...         NaN
# 774                      NaN                             NaN  ...         NaN
# 775                      NaN                             NaN  ...         NaN
# 776                      NaN                             NaN  ...         NaN
#
#     Unnamed: 24 Unnamed: 25  Unnamed: 26  Unnamed: 27  Unnamed: 28  \
# 0           NaN         NaN          NaN          NaN          NaN
# 1           NaN         NaN          NaN          NaN          NaN
# 2           NaN         NaN          NaN          NaN          NaN
# 3           NaN         NaN          NaN          NaN          NaN
# 4           NaN         NaN          NaN          NaN          NaN
# ..          ...         ...          ...          ...          ...
# 772         NaN         NaN          NaN          NaN          NaN
# 773         NaN         NaN          NaN          NaN          NaN
# 774         NaN         NaN          NaN          NaN          NaN
# 775         NaN         NaN          NaN          NaN          NaN
# 776         NaN         NaN          NaN          NaN          NaN
#
#      Unnamed: 29  Unnamed: 30  Unnamed: 31  Unnamed: 32
# 0            NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...
# 772          NaN          NaN          NaN          NaN
# 773          NaN          NaN          NaN          NaN
# 774          NaN          NaN          NaN          NaN
# 775          NaN          NaN          NaN          NaN
# 776          NaN          NaN          NaN          NaN
#
# [777 rows x 33 columns]
