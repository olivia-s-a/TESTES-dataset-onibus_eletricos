# %% [markdown]
# ## Tratamento data e hora das posições

# %% [markdown]
# Nesse notebook são tratadas a data e hora das posições dos ônibus

# %%
import pandas as pd
from utils.load_csv import load_csv
from utils.save_csv import save_csv

# %%
df_posicoes = load_csv('df_posicoes.csv')

# %%
df_posicoes["timestamp"] = pd.to_datetime(df_posicoes["timestamp"])

# %%
df_posicoes['timestamp'] = df_posicoes['timestamp'].dt.tz_convert("America/Sao_Paulo")

df_posicoes
# Out:
#           linha  id_onibus                 timestamp        lat        lon  \
# 0       5010-10      68853 2025-10-02 12:48:43-03:00 -23.649045 -46.640405
# 1       5010-10      68383 2025-10-02 12:48:52-03:00 -23.662680 -46.631144
# 2       5010-10      68142 2025-10-02 12:49:09-03:00 -23.642878 -46.656716
# 3       5010-10      68338 2025-10-02 12:49:12-03:00 -23.662680 -46.631144
# 4       5010-10      68362 2025-10-02 12:49:06-03:00 -23.644669 -46.673169
# ...         ...        ...                       ...        ...        ...
# 149815  4092-10      47857 2025-10-02 12:56:07-03:00 -23.580189 -46.419959
# 149816  7062-10      78133 2025-10-02 12:56:21-03:00 -23.641820 -46.766292
# 149817  7053-22      78167 2025-10-02 12:55:46-03:00 -23.637100 -46.779115
# 149818  4008-21      48384 2025-10-02 12:56:26-03:00 -23.578815 -46.432018
# 149819  6051-31      66865 2025-10-02 12:56:07-03:00 -23.763236 -46.689578
#
#         is_eletrico            modelo
# 0             False  Articulado (18m)
# 1             False        Midiônibus
# 2             False            Padron
# 3             False  Articulado (23m)
# 4             False            Básico
# ...             ...               ...
# 149815        False            Padron
# 149816        False        Midiônibus
# 149817        False      Biarticulado
# 149818        False            Padron
# 149819        False  Articulado (18m)
#
# [149820 rows x 7 columns]

# %%
save_csv(df_posicoes, 'df_posicoes.csv')
# Out:
# Base salva em data\df_posicoes.csv
